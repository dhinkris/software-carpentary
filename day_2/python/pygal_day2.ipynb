# %%
from IPython.display import SVG

# %%
import pandas as pd #aliasing
import pygal as pg
dem_data=dem_health_data = pd.read_csv("Dem_Health_Full.txt",sep="\t")

# %%
dem_data.head(2)
# Out:
#     County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0  Autauga    AL                  82     10.4               5.9     16.6
# 1  Baldwin    AL                 102     10.2               7.1     14.3
#
#    Total_Births  Total_Deaths
# 0        3048.0        1867.0
# 1        5471.0        4388.0

# %%
dir (dem_data)
# Out:
# ['County',
#  'Infant_Mortality',
#  'Population_Density',
#  'Poverty',
#  'State',
#  'Suicide',
#  'T',
#  'Total_Births',
#  'Total_Deaths',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
dem_data.loc[0:2,['County','Poverty']]
dem_data.iloc[0,2:4]
dem_data[(dem_data['State']=='AL')|(dem_data['State']=='TX')]
# Out:
#           County State  Population_Density  Poverty  Infant_Mortality  \
# 0        Autauga    AL                  82     10.4               5.9
# 1        Baldwin    AL                 102     10.2               7.1
# 2        Barbour    AL                  32     22.1               7.1
# 3           Bibb    AL                  35     16.8               9.8
# 4         Blount    AL                  86     11.9               9.0
# 5        Bullock    AL                  18     26.2              13.3
# 6         Butler    AL                  27     20.0               5.8
# 7        Calhoun    AL                 184     16.4               9.5
# 8       Chambers    AL                  59     16.2               7.5
# 9       Cherokee    AL                  44     15.2               7.4
# 10       Chilton    AL                  60     14.9              10.5
# 11       Choctaw    AL                  16     18.7              10.8
# ...

# %%
dem_data.iloc[3126]
dem_data.fillna(0,inplace=True)
# Out:
# County                Hot Springs
# State                          WY
# Population_Density              2
# Poverty                      11.6
# Infant_Mortality                0
# Suicide                      23.9
# Total_Births                  437
# Total_Deaths                  627
# Name: 3126, dtype: object

# %%
dem_data.loc[(dem_data[] < 0), :] = 0
# Out:
#   File "<ipython-input-47-e6bb1326cc80>", line 1
#     dem_data.loc[(dem_data[] < 0), :] = 0
#                            ^
# SyntaxError: invalid syntax

# %%
dem_data
# Out:
#            County State  Population_Density  Poverty  Infant_Mortality  \
# 0         Autauga    AL                  82     10.4               5.9
# 1         Baldwin    AL                 102     10.2               7.1
# 2         Barbour    AL                  32     22.1               7.1
# 3            Bibb    AL                  35     16.8               9.8
# 4          Blount    AL                  86     11.9               9.0
# 5               0     0                   0      0.0               0.0
# 6          Butler    AL                  27     20.0               5.8
# 7         Calhoun    AL                 184     16.4               9.5
# 8        Chambers    AL                  59     16.2               7.5
# 9        Cherokee    AL                  44     15.2               7.4
# 10        Chilton    AL                  60     14.9              10.5
# 11        Choctaw    AL                  16     18.7              10.8
# ...

# %%
dem_data['Suicide'].replace(dem_data.loc[:,4]<0,0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-25622864756a> in <module>()
# ----> 1 dem_data['Suicide'].replace(dem_data.loc[:,4]<0,0,inplace=True)
#
# C:\Users\dhineshvikram\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1308
#    1309         if type(key) is tuple:
# -> 1310             return self._getitem_tuple(key)
#    1311         else:
#    1312             return self._getitem_axis(key, axis=0)
#
# C:\Users\dhineshvikram\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     794     def _getitem_tuple(self, tup):
#     795         try:
# --> 796             return self._getitem_lowerdim(tup)
#     797         except IndexingError:
#     798             pass
#
# C:\Users\dhineshvikram\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
# ...

# %%
dem_data.loc[2,:]
# Out:
# County                Barbour
# State                      AL
# Population_Density         32
# Poverty                  22.1
# Infant_Mortality          7.1
# Suicide                  10.3
# Total_Births             1835
# Total_Deaths             1538
# Name: 2, dtype: object

# %%
dem_data
# Out:
#            County State  Population_Density  Poverty  Infant_Mortality  \
# 0         Autauga    AL                  82     10.4               5.9
# 1         Baldwin    AL                 102     10.2               7.1
# 2         Barbour    AL                  32     22.1               7.1
# 3            Bibb    AL                  35     16.8               9.8
# 4          Blount    AL                  86     11.9               9.0
# 5               0     0                   0      0.0               0.0
# 6          Butler    AL                  27     20.0               5.8
# 7         Calhoun    AL                 184     16.4               9.5
# 8        Chambers    AL                  59     16.2               7.5
# 9        Cherokee    AL                  44     15.2               7.4
# 10        Chilton    AL                  60     14.9              10.5
# 11        Choctaw    AL                  16     18.7              10.8
# ...

# %%
a_tupe=(2,3)

# %%
type (a_tupe)
# Out:
# tuple

# %%
a_list=[12,2]

# %%
type(a_list)
# Out:
# list

# %%
nested_list=[(2,3),(3,3)]

# %%
type(nested_list)
# Out:
# list

# %%
nested_list
# Out:
# [(2, 3), (3, 3)]

# %%
nested_list[1]
# Out:
#   File "<ipython-input-70-ea4083e88115>", line 1
#     nested_list[1].(1)
#                    ^
# SyntaxError: invalid syntax

# %%
dem_AL = dem_data.loc[dem_data['State']=='AL', ['Population_Density','Poverty']]
dem_TX = dem_data.loc[dem_data['State']=='TX', ['Population_Density','Poverty']]

# %%
lst_AL=[tuple(x) for x in dem_AL.values]
lst_TX=[tuple(x) for x in dem_TX.values]

# %%
scatter_plot=pg.XY(stroke=True, x_title="Poverty",y_title="Population Density")
scatter_plot.add('Alabama',lst_AL)
scatter_plot.add('Texas',lst_TX)
SVG (scatter_plot.render())

# %%
def pov_vs_pop (states):
    dem_states = dem_data.loc[dem_data['State']==states, ['Population_Density','Poverty']]
    lst_states=[tuple(x) for x in dem_states.values]
    scatter_plot=pg.XY(stroke=False, x_title="Poverty",y_title="Population Density")
    scatter_plot.add(states,lst_states)
    scatter_plot.range = 40 100]
    return SVG (scatter_plot.render())

# %%
pov_vs_pop ("TX")

# %%
for i in range(0,6,2):
    print (i)
# Out:
# 0
# 2
# 4

# %%
def pov_vs_pop (states):
    dem_states = dem_data.loc[dem_data['State']==states, ['Population_Density','Poverty']]
    lst_states=[tuple(x) for x in dem_states.values]
    scatter_plot=pg.XY(stroke=False, x_title="Poverty",y_title="Population Density",xrange=(0,100))
    #scatter_plot.x_labels = (i for i in range(0,2000,100))
    scatter_plot.add(states,lst_states)
    return SVG (scatter_plot.render())

# %%
pov_vs_pop (["TX","AZ"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-201-5ba2ac7bdc68> in <module>()
# ----> 1 pov_vs_pop (["TX","AZ"])
#
# <ipython-input-197-7a7d93c0ec37> in pov_vs_pop(states)
#       1 def pov_vs_pop (states):
# ----> 2     dem_states = dem_data.loc[dem_data['State']==states, ['Population_Density','Poverty']]
#       3     lst_states=[tuple(x) for x in dem_states.values]
#       4     scatter_plot=pg.XY(stroke=False, x_title="Poverty",y_title="Population Density",xrange=(0,100))
#       5     #scatter_plot.x_labels = (i for i in range(0,2000,100))
#
# C:\Users\dhineshvikram\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
# ...

# %%
def pov_vs_pop (states):
    dem_states = dem_data.loc[dem_data['State']==states, ['Population_Density','Poverty']]
    lst_states=[tuple(x) for x in dem_states.values]
    scatter_plot=pg.XY(stroke=False, x_title="Poverty",y_title="Population Density",range=(0,100),dots_size=4)
    scatter_plot.x_labels = (i for i in range(0,2000,100))
    scatter_plot.add(states,lst_states)
    return SVG (scatter_plot.render())

# %%
al = dem_data.loc[dem_data['State']=='TX', ['Population_Density','Poverty']]
mean_pov_al = al['Poverty'].mean()
mean_pov_al
# Out:
# 16.92166666666667

# %%
def mean_of_column (state_name, column_name):
    al = dem_data.loc[dem_data['State']==state_name, [column_name]]
    mean_pov_al = al[column_name].mean()
    return mean_pov_al

# %%
# Out:
# 16.92166666666667

# %%
bar_chart=pg.Bar()
bar_chart.title='Mean of Poverty across all states'
for state in list(lststate):
    bar_chart.add(state,mean_of_column(state,'Poverty'))
SVG(bar_chart.render())

# %%
dem_data['State'].unique()
# Out:
# array(['AL', 0, 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
lststate=[]
for i in list(dem_data['State'].unique()):
    if (i!=0):
        lststate.append(i)

# %%
for state in list(dem_data['State'].unique())
# Out:
#   File "<ipython-input-182-435c8dd95bd0>", line 1
#     for state in list(dem_data['State'].unique())
#                                                  ^
# SyntaxError: invalid syntax
